# %% [markdown]
# Faça uma função calculadora que os números e as operações serão feitas pelo usuário. O código deve ficar rodando infinitamente até que o usuário escolha a opção de sair. No início, o programa mostrará a seguinte lista de operações:
#
# 1: Soma
# 2: Subtração
# 3: Multiplicação
# 4: Divisão
# 0: Sair
#
# Digite o número para a operação correspondente e caso o usuário introduza qualquer outro, o sistema deve mostrar a mensagem “Essa opção não existe” e voltar ao menu de opções.
#
# Após a seleção, o sistema deve pedir para o usuário inserir o primeiro e segundo valor, um de cada. Depois precisa executar a operação e mostrar o resultado na tela. Quando o usuário escolher a opção “Sair”, o sistema irá parar.
#
# É necessário que o sistema mostre as opções sempre que finalizar uma operação e mostrar o resultado.

# %%
print("Bem vindo a Calculadora")
print("Escolha uma operação:")
print("1: Soma")
print("2: Subtração")
print("3: Multiplicação")
print("4: Divisão")
print("0: Sair")

escolha = input("Digite o número da opção desejada: ")


print("Escolha uma operação:")
print ("Escreva abaixo o 1º Número")
num1 = float(input())
print ("Escreva qual operação")
operador = str(input())
print ("Escreva abaixo o 2º Número")
num2 = float(input())
print (f"{num1} {operador} {num2}")
# Out:
# Bem vindo a Calculadora
# Escolha uma operação:
# 1: Soma
# 2: Subtração
# 3: Multiplicação
# 4: Divisão
# 0: Sair
# Escolha uma operação:
# Escreva abaixo o 1º Número
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 14
#      12 print("Escolha uma operação:")
#      13 print ("Escreva abaixo o 1º Número")
# ---> 14 num1 = float(input())
#      15 print ("Escreva qual operação")
#      16 operador = str(input())
#
# ValueError: could not convert string to float: ''

# %%
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

def calculadora():
    while True:
        print("Escolha uma operação:")
        print("1: Soma")
        print("2: Subtração")
        print("3: Multiplicação")
        print("4: Divisão")
        print("0: Sair")

        escolha = input("Digite o número da operação desejada: ")

        if escolha == '0':
            print("Saindo do programa.")
            break  # Sai do loop quando a escolha é '0'

        operacao = operacoes.get(escolha)
        if operacao:
            operacao()
        else:
            print("Escolha inválida. Por favor, escolha uma operação válida.")

calculadora()

# %%
def soma():
    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número: "))
    resultado = num1 + num2
    print(f"Resultado: {num1} + {num2} = {resultado}")

def subtracao():
    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número: "))
    resultado = num1 - num2
    print(f"Resultado: {num1} - {num2} = {resultado}")

def multiplicacao():
    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número: "))
    resultado = num1 * num2
    print(f"Resultado: {num1} * {num2} = {resultado}")

def divisao():
    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número (não pode ser zero): "))
    if num2 == 0:
        print("Erro: Divisão por zero.")
    else:
        resultado = num1 / num2
        print(f"Resultado: {num1} / {num2} = {resultado}")

def sair():
    global operacoes
    print("Saindo do programa.")
    operacoes = False

operacoes = {
    '1': soma,
    '2': subtracao,
    '3': multiplicacao,
    '4': divisao,
    '0': sair
}

def calculadora():
    while operacoes:
        print("Escolha uma operação:")
        print("1: Soma")
        print("2: Subtração")
        print("3: Multiplicação")
        print("4: Divisão")
        print("0: Sair")

        escolha = input("Digite o número da operação desejada: ")

        operacao = operacoes.get(escolha)
        if operacao:
            operacao()
        else:
            print("Escolha inválida. Por favor, escolha uma operação válida.")


calculadora()

# %%
operacoes = True

def calculadora():
    while operacoes == True:
        print("Escolha uma operação:")
        print("1: Soma")
        print("2: Subtração")
        print("3: Multiplicação")
        print("4: Divisão")
        print("0: Sair")

        print("Digite o número da operação desejada: ")
        escolha = input("Digite o número da operação desejada: ")

        if escolha in operacoes:
            operacoes[escolha]()
        else:
            print("Escolha inválida. Por favor, escolha uma operação válida.")

operacoes = {
'1': soma,
'2': subtracao,
'3': multiplicacao,
'4': divisao,
'0': sair
}

def sair():
    if operacoes ==True:
        print("Saindo do programa.")
        operacoes = False
    else:
        operacoes = True
        
    def soma():
        num1 = float(input("Digite o primeiro número: "))
        num2 = float(input("Digite o segundo número: "))
        resultado = num1 + num2
        print(f"Resultado: {num1} + {num2} = {resultado}")

    def subtracao():
        num1 = float(input("Digite o primeiro número: "))
        num2 = float(input("Digite o segundo número: "))
        resultado = num1 - num2
        print(f"Resultado: {num1} - {num2} = {resultado}")

    def multiplicacao():
        num1 = float(input("Digite o primeiro número: "))
        num2 = float(input("Digite o segundo número: "))
        resultado = num1 * num2
        print(f"Resultado: " + str(num1) +"X" + str(num2) + "=" + str(resultado))

    def divisao():
        num1 = float(input("Digite o primeiro número: "))
        num2 = float(input("Digite o segundo número (não pode ser zero): "))
        if num2 == 0:
            print("Erro: Divisão por zero.")
        else:
            resultado = num1 / num2
            print(f"Resultado: {num1} / {num2} = {resultado}")
            #    print(f"Resultado: " + str(num1) +"X" + str(num2) + "=" + str(resultado))
calculadora()

# %%
while True:
    print("Escolha uma operação:")
    print("1: Soma")
    print("2: Subtração")
    print("3: Multiplicação")
    print("4: Divisão")
    print("0: Sair")

    escolha = input("Digite o número da operação desejada: ")

    if escolha == '0':
        print("Saindo do programa.")
        break
    elif escolha == '1':
        num1 = float(input("Digite o primeiro número: "))
        num2 = float(input("Digite o segundo número: "))
        resultado = num1 + num2
        print(f"Resultado: {resultado}")
    elif escolha == '2':
        num1 = float(input("Digite o primeiro número: "))
        num2 = float(input("Digite o segundo número: "))
        resultado = num1 - num2
        print(f"Resultado: {resultado}")
    elif escolha == '3':
        num1 = float(input("Digite o primeiro número: "))
        num2 = float(input("Digite o segundo número: "))
        resultado = num1 * num2
        print(f"Resultado: {resultado}")
    elif escolha == '4':
        num1 = float(input("Digite o primeiro número: "))
        num2 = float(input("Digite o segundo número (não pode ser zero): "))
        if num2 == 0:
            print("Erro: Divisão por zero.")
        else:
            resultado = num1 / num2
            print(f"Resultado: {resultado}")
    else:
        print("Escolha inválida. Por favor, escolha uma operação válida.")

# %%
import math

def soma():
    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número: "))
    resultado = num1 + num2
    print(f"Resultado: {resultado}")

def subtracao():
    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número: "))
    resultado = num1 - num2
    print(f"Resultado: {resultado}")

def multiplicacao():
    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número: "))
    resultado = num1 * num2
    print(f"Resultado: {resultado}")

def divisao():
    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número (não pode ser zero): "))
    if num2 == 0:
        print("Erro: Divisão por zero.")
    else:
        resultado = num1 / num2
        print(f"Resultado: {resultado}")

def sair():
    print("Saindo do programa.")

operacoes = {
    '1': soma,
    '2': subtracao,
    '3': multiplicacao,
    '4': divisao,
    '0': sair
}

def menu():
    while True:
        print("Escolha uma operação:")
        print("1: Soma")
        print("2: Subtração")
        print("3: Multiplicação")
        print("4: Divisão")
        print("0: Sair")

        escolha = input("Digite o número da operação desejada: ")

        try:
            operacao = operacoes[escolha]
            operacao()
        except KeyError:
            print("Escolha inválida. Por favor, escolha uma operação válida.")

menu()
